# %%
# %matplotlib inline
from IPython.display import clear_output, Image as Jmage, display
import os
from PIL import Image
import signal
import subprocess
import sys
import time


def display_image(path):
    try:
        display(Image.open(path))
    except:
        print(f'no image: {path}')

def probe_state(app_key, state_png_path, clear=False):
    try:
        subprocess.run(['pkill', '-HUP', '-f', app_key], check=False)
        time.sleep(1)
        if clear:
            clear_output(False)
    except:
        pass
    display_image(state_png_path)

# %% [markdown]
# # Solved:

# %%
probe_state('cartpole-a2c-pytorch', './cartpole/state-cartpole-a2c-pytorch.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1500x500 at 0x7F3180D31400>

# %%
probe_state('cartpole-dueling-dqn-pytorch', './cartpole/state-cartpole-dueling-dqn-pytorch.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1500x500 at 0x7F3187E46FD0>

# %%
probe_state('cartpole-ddqn-pytorch', './cartpole/state-cartpole-ddqn-pytorch.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1500x500 at 0x7F3187E46EB8>

# %%
probe_state('cartpole-dqn-pytorch', './cartpole/state-cartpole-dqn-pytorch.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1500x500 at 0x7F3187DED128>

# %%
probe_state('pong-cnn-ddqn-pytorch', './pong/state-pong-cnn-ddqn-pytorch.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1500x500 at 0x7F3187DED7B8>

# %%
probe_state('pong-cnn-dueling-dqn-pytorch', './pong/state-pong-cnn-dueling-dqn-pytorch.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1500x500 at 0x7F3187DEDAC8>

# %%
probe_state('pong-cnn-a2c-pytorch', './pong/state-pong-cnn-a2c-pytorch.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1500x500 at 0x7F3187DEDAC8>

# %%
display_image('../jupyter/pong/state-pong-dueling-raw-dqn.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1512x360 at 0x7F3187DED828>

# %%
display_image('../jupyter/pong/state-pong-raw-dqn.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1512x360 at 0x7F3187DED860>

# %%
display_image('../jupyter/pong/state-pong-priority-replay-dqn.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1512x360 at 0x7F3187DED5C0>

# %%
display_image('../jupyter/pong/state-pong-priority-replay-v2-dqn.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1368x360 at 0x7F3187DEDBA8>

# %%
display_image('../jupyter/pong/state-pong-dqn-mixed.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1296x360 at 0x7F3187DEDCC0>

# %% [markdown]
# # Unsolved:

# %%
while True:
    clear_output(False)
    #probe_state('tennis-cnn-a2c-pytorch', './tennis/state-tennis-cnn-a2c-pytorch.png')
    display_image('../jupyter/pong/state-pong-double-dqn-dumb.png')
    display_image('../jupyter/pong/state-pong-double-dqn-original.png')
    display_image('../jupyter/breakout/state-breakout-dqn-mixed.png')
    time.sleep(15 * 60)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1512x360 at 0x7F3187DED630>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1296x360 at 0x7F3187DF4198>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1296x360 at 0x7F3187DED0F0>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-151c7006caae> in <module>
#       5     display_image('../jupyter/pong/state-pong-double-dqn-original.png')
#       6     display_image('../jupyter/breakout/state-breakout-dqn-mixed.png')
# ----> 7     time.sleep(15 * 60)
#
# KeyboardInterrupt:
