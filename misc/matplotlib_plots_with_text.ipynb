# %%
# %matplotlib inline
import matplotlib.pyplot as plot
import numpy as np

# %%
img = np.random.random((32, 32))

# %%
plot.imshow(img)
plot.title('title')
buf, (w, h) = fig.canvas.print_to_buffer()
X = np.frombuffer(buf, np.uint8).reshape(h, w, 4)

# %%
import io
plot.imshow(img)
with io.BytesIO() as buf:
    plot.savefig(buf, format='png')
    svg = buf.getvalue()
with io.BytesIO(svg) as buf:
    plot.imshow(plot.imread(buf, format='png'))

# %%
plot.imshow(X)
